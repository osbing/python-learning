# %%
import os
print(os.popen('systeminfo').read())
print(os.popen('ipconfig /all').read())
# Out:
# 主机名:           WIN-FPG1G93AEEI
# OS 名称:          Microsoft Windows Server 2016 Datacenter
# OS 版本:          10.0.14393 暂缺 Build 14393
# OS 制造商:        Microsoft Corporation
# OS 配置:          独立服务器
# OS 构件类型:      Multiprocessor Free
# 注册的所有人:     暂缺
# 注册的组织:       暂缺
# 产品 ID:          00376-40000-00000-AA336
# 初始安装日期:     2017/7/16, 9:58:28
# 系统启动时间:     2019/1/3, 12:58:06
# 系统制造商:       Micro-Star International Co., Ltd.
# 系统型号:         GL62 6QD
# 系统类型:         x64-based PC
# 处理器:           安装了 1 个处理器。
#                   [01]: Intel64 Family 6 Model 94 Stepping 3 GenuineIntel ~2300 Mhz
# BIOS 版本:        American Megatrends Inc. E16J6IMS.103, 2016/1/4
# Windows 目录:     C:\Windows
# 系统目录:         C:\Windows\system32
# 启动设备:         \Device\HarddiskVolume1
# 系统区域设置:     zh-cn;中文(中国)
# 输入法区域设置:   zh-cn;中文(中国)
# 时区:             (UTC+08:00) 北京，重庆，香港特别行政区，乌鲁木齐
# 物理内存总量:     24,485 MB
# 可用的物理内存:   17,453 MB
# 虚拟内存: 最大值: 26,021 MB
# 虚拟内存: 可用:   17,022 MB
# 虚拟内存: 使用中: 8,999 MB
# 页面文件位置:     C:\pagefile.sys
# 域:               WORKGROUP
# 登录服务器:       \\WIN-FPG1G93AEEI
# 修补程序:         安装了 14 个修补程序。
#                   [01]: KB3186568
#                   [02]: KB3192137
#                   [03]: KB4013418
#                   [04]: KB4023834
#                   [05]: KB4035631
#                   [06]: KB4049065
#                   [07]: KB4054590
#                   [08]: KB4054592
#                   [09]: KB4089510
#                   [10]: KB4091664
#                   [11]: KB4093137
#                   [12]: KB4132216
#                   [13]: KB4465659
#                   [14]: KB4483229
# 网卡:             安装了 6 个 NIC。
#                   [01]: Intel(R) Dual Band Wireless-AC 3165
#                       连接名:      WLAN
#                       状态:        媒体连接已中断
#                   [02]: Qualcomm Atheros AR8171/8175 PCI-E Gigabit Ethernet Controller (NDIS 6.30)
#                       连接名:      以太网
#                       启用 DHCP:   是
#                       DHCP 服务器: 192.168.1.1
#                       IP 地址
#                         [01]: 192.168.1.102
#                         [02]: fe80::4c58:10f9:5f9b:df87
#                   [03]: Microsoft KM-TEST Loopback Adapter
#                       连接名:      Npcap Loopback Adapter
#                       启用 DHCP:   是
#                       DHCP 服务器: 255.255.255.255
#                       IP 地址
#                         [01]: 169.254.70.113
#                         [02]: fe80::3083:9095:b095:4671
#                   [04]: VMware Virtual Ethernet Adapter for VMnet1
#                       连接名:      VMware Network Adapter VMnet1
#                       启用 DHCP:   是
#                       DHCP 服务器: 192.168.175.254
#                       IP 地址
#                         [01]: 192.168.175.1
#                         [02]: fe80::7583:e90f:9be8:af4a
#                   [05]: VMware Virtual Ethernet Adapter for VMnet8
#                       连接名:      VMware Network Adapter VMnet8
#                       启用 DHCP:   否
#                       IP 地址
#                         [01]: 192.168.136.2
#                         [02]: fe80::7c8b:add9:5e8f:922f
#                   [06]: VMware Virtual Ethernet Adapter for VMnet2
#                       连接名:      VMware Network Adapter VMnet2
#                       启用 DHCP:   否
#                       IP 地址
#                         [01]: 169.254.78.186
#                         [02]: fe80::ad31:74b5:9fc1:4eba
# Hyper-V 要求:     已检测到虚拟机监控程序。将不显示 Hyper-V 所需的功能。
#
#
# Windows IP 配置
#
#    主机名  . . . . . . . . . . . . . : WIN-FPG1G93AEEI
#    主 DNS 后缀 . . . . . . . . . . . :
#    节点类型  . . . . . . . . . . . . : 混合
#    IP 路由已启用 . . . . . . . . . . : 否
#    WINS 代理已启用 . . . . . . . . . : 否
#
# 以太网适配器 Npcap Loopback Adapter:
#
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : Npcap Loopback Adapter
#    物理地址. . . . . . . . . . . . . : 02-00-4C-4F-4F-50
#    DHCP 已启用 . . . . . . . . . . . : 是
#    自动配置已启用. . . . . . . . . . : 是
#    本地链接 IPv6 地址. . . . . . . . : fe80::3083:9095:b095:4671%16(首选)
#    自动配置 IPv4 地址  . . . . . . . : 169.254.70.113(首选)
#    子网掩码  . . . . . . . . . . . . : 255.255.0.0
#    默认网关. . . . . . . . . . . . . :
#    DHCPv6 IAID . . . . . . . . . . . : 838991948
#    DHCPv6 客户端 DUID  . . . . . . . : 00-01-00-01-20-FC-84-4C-02-00-4C-4F-4F-50
#    DNS 服务器  . . . . . . . . . . . : fec0:0:0:ffff::1%1
#                                        fec0:0:0:ffff::2%1
#                                        fec0:0:0:ffff::3%1
#    TCPIP 上的 NetBIOS  . . . . . . . : 已启用
#
# 无线局域网适配器 WLAN:
#
#    媒体状态  . . . . . . . . . . . . : 媒体已断开连接
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : Intel(R) Dual Band Wireless-AC 3165
#    物理地址. . . . . . . . . . . . . : 08-D4-0C-7C-64-B0
#    DHCP 已启用 . . . . . . . . . . . : 是
#    自动配置已启用. . . . . . . . . . : 是
#
# 无线局域网适配器 本地连接* 11:
#
#    媒体状态  . . . . . . . . . . . . : 媒体已断开连接
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : Microsoft Wi-Fi Direct Virtual Adapter
#    物理地址. . . . . . . . . . . . . : 08-D4-0C-7C-64-B1
#    DHCP 已启用 . . . . . . . . . . . : 是
#    自动配置已启用. . . . . . . . . . : 是
#
# 以太网适配器 以太网:
#
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : Qualcomm Atheros AR8171/8175 PCI-E Gigabit Ethernet Controller (NDIS 6.30)
#    物理地址. . . . . . . . . . . . . : D8-CB-8A-F0-B0-35
#    DHCP 已启用 . . . . . . . . . . . : 是
#    自动配置已启用. . . . . . . . . . : 是
#    本地链接 IPv6 地址. . . . . . . . : fe80::4c58:10f9:5f9b:df87%15(首选)
#    IPv4 地址 . . . . . . . . . . . . : 192.168.1.102(首选)
#    子网掩码  . . . . . . . . . . . . : 255.255.255.0
#    获得租约的时间  . . . . . . . . . : 2019年1月3日 12:58:28
#    租约过期的时间  . . . . . . . . . : 2019年1月3日 16:58:19
#    默认网关. . . . . . . . . . . . . : 192.168.1.1
#    DHCP 服务器 . . . . . . . . . . . : 192.168.1.1
#    DHCPv6 IAID . . . . . . . . . . . : 517524362
#    DHCPv6 客户端 DUID  . . . . . . . : 00-01-00-01-20-FC-84-4C-02-00-4C-4F-4F-50
#    DNS 服务器  . . . . . . . . . . . : 202.96.134.33
#                                        202.96.128.86
#    TCPIP 上的 NetBIOS  . . . . . . . : 已启用
#
# 以太网适配器 VMware Network Adapter VMnet1:
#
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : VMware Virtual Ethernet Adapter for VMnet1
#    物理地址. . . . . . . . . . . . . : 00-50-56-C0-00-01
#    DHCP 已启用 . . . . . . . . . . . : 是
#    自动配置已启用. . . . . . . . . . : 是
#    本地链接 IPv6 地址. . . . . . . . : fe80::7583:e90f:9be8:af4a%6(首选)
#    IPv4 地址 . . . . . . . . . . . . : 192.168.175.1(首选)
#    子网掩码  . . . . . . . . . . . . : 255.255.255.0
#    获得租约的时间  . . . . . . . . . : 2019年1月3日 12:58:32
#    租约过期的时间  . . . . . . . . . : 2019年1月3日 16:13:20
#    默认网关. . . . . . . . . . . . . :
#    DHCP 服务器 . . . . . . . . . . . : 192.168.175.254
#    DHCPv6 IAID . . . . . . . . . . . : 1090539606
#    DHCPv6 客户端 DUID  . . . . . . . : 00-01-00-01-20-FC-84-4C-02-00-4C-4F-4F-50
#    DNS 服务器  . . . . . . . . . . . : fec0:0:0:ffff::1%1
#                                        fec0:0:0:ffff::2%1
#                                        fec0:0:0:ffff::3%1
#    TCPIP 上的 NetBIOS  . . . . . . . : 已启用
#
# 以太网适配器 VMware Network Adapter VMnet8:
#
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : VMware Virtual Ethernet Adapter for VMnet8
#    物理地址. . . . . . . . . . . . . : 00-50-56-C0-00-08
#    DHCP 已启用 . . . . . . . . . . . : 否
#    自动配置已启用. . . . . . . . . . : 是
#    本地链接 IPv6 地址. . . . . . . . : fe80::7c8b:add9:5e8f:922f%9(首选)
#    IPv4 地址 . . . . . . . . . . . . : 192.168.136.2(首选)
#    子网掩码  . . . . . . . . . . . . : 255.255.255.0
#    默认网关. . . . . . . . . . . . . :
#    DHCPv6 IAID . . . . . . . . . . . : 1124094038
#    DHCPv6 客户端 DUID  . . . . . . . : 00-01-00-01-20-FC-84-4C-02-00-4C-4F-4F-50
#    DNS 服务器  . . . . . . . . . . . : 8.8.8.8
#    TCPIP 上的 NetBIOS  . . . . . . . : 已启用
#
# 以太网适配器 VMware Network Adapter VMnet2:
#
#    连接特定的 DNS 后缀 . . . . . . . :
#    描述. . . . . . . . . . . . . . . : VMware Virtual Ethernet Adapter for VMnet2
#    物理地址. . . . . . . . . . . . . : 00-50-56-C0-00-02
#    DHCP 已启用 . . . . . . . . . . . : 否
#    自动配置已启用. . . . . . . . . . : 是
#    本地链接 IPv6 地址. . . . . . . . : fe80::ad31:74b5:9fc1:4eba%4(首选)
#    自动配置 IPv4 地址  . . . . . . . : 169.254.78.186(首选)
#    子网掩码  . . . . . . . . . . . . : 255.255.0.0
#    默认网关. . . . . . . . . . . . . :
#    DHCPv6 IAID . . . . . . . . . . . : 1191202902
#    DHCPv6 客户端 DUID  . . . . . . . : 00-01-00-01-20-FC-84-4C-02-00-4C-4F-4F-50
#    DNS 服务器  . . . . . . . . . . . : fec0:0:0:ffff::1%1
#                                        fec0:0:0:ffff::2%1
#                                        fec0:0:0:ffff::3%1
#    TCPIP 上的 NetBIOS  . . . . . . . : 已启用

# %%
import os
command_1 = 'systeminfo |findstr /R "初始安装日期 系统启动时间 处理器 物理内存总量 登录服务器"' #正则
command_2 = 'ping www.baidu.com -l 1024 -n 1'
command_3 = 'gpupdate'
print(os.popen(command_1).read())
print(os.popen(command_2).read())
print(command_3)
print(os.popen(command_3).read())

# %%
import os
command_1 = 'systeminfo |findstr /R "初始安装日期 系统启动时间 处理器 物理内存总量 登录服务器"' #正则
command_2 = 'ping www.baidu.com -l 1024 -n 1'
command_3 = 'gpupdate'
print(os.popen(command_1).read())
print(os.popen(command_2).read())
print(command_3)
print(os.popen(command_3).read())
